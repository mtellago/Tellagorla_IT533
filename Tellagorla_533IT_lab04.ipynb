# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import spatial
import statsmodels.api as sm
from statsmodels.formula.api import ols

from sklearn import linear_model
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

#Reading in the data as adult dataframe
amazon = pd.read_csv("https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/amazon_toy_sample_clean.csv", encoding="ISO-8859-1")

#Verifying that we can see the data
amazon.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             uniq_id  \
# 0  dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1  ba85fb9368114fce646379ed12750a5f
# 2  14e24c29ba38c2717754baa2638f242a
# 3  048d64d2ba61c23f6280663a7281ff19
# 4  7b72f597db5d74d35c4f91ef69708cf1
#
#                                         product_name  \
# 0                                      Dinosaur Eggs
# 1   Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2          Latex Assorted Water Balloons, Pack of 40
# 3                iCarly Shopper Bag - Lilac and Pink
# 4  4 Packs of Mini Colouring Pencils (4 pencils i...
#
#                manufacturer  price  number_available_in_stock status  \
# 0                   Halsall   0.29                          3    new
# 1                   Neopets   0.38                          2    new
# 2              Unique Party   0.39                          7    new
# 3    Trade Mark Collections   0.50                          4    new
# 4  unisex party bag fillers   0.60                          7    new
#
#    number_of_reviews  number_of_answered_questions  \
# 0                  3                             2
# 1                  2                             1
# 2                  2                             1
# 3                  7                             2
# 4                 21                             1
#
#    average_review_rating_of_5  \
# 0                         4.0
# 1                         4.5
# 2                         4.5
# 3                         4.6
# 4                         4.3
#
#                     amazon_category_and_sub_category  \
# 0                     Figures & Playsets > Dinosaurs
# 1  Hobbies > Trading Cards & Accessories > Packs ...
# 2            Party Supplies > Decorations > Balloons
# 3  Sports Toys & Outdoor > Beach Toys > Airbeds &...
# 4                  Arts & Crafts > Colouring Pencils
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                            Unknown
# 2  http://www.amazon.co.uk/Latex-Cannonball | htt...
# 3  http://www.amazon.co.uk/iCarly-Large-Rectangle...
# 4  http://www.amazon.co.uk/12-Mini-Christmas-Colo...
#
#                                          description  \
# 0           Manufacturer's Description not available
# 1           Manufacturer's Description not available
# 2  Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3  Manufacturer's Description The iCarly Shopping...
# 4  4 x Mini Colouring Pencils - Pack of 4 Size: 8...
#
#                                  product_information  \
# 0  Technical Details Item Weight82 g Product Dime...
# 1  Technical Details Item Weight454 g Product Dim...
# 2  Technical Details Item Weight222 g Product Dim...
# 3                                                NaN
# 4  Technical Details Item Weight59 g Product Dime...
#
#                                  product_description  \
# 0                                      Not available
# 1                                      Not available
# 2  Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3  Manufacturer's Description The iCarly Shopping...
# 4  4 x Mini Colouring Pencils - Pack of 4 Size: 8...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                      Not available
# 2  http://www.amazon.co.uk/Water-Bombs-Pack-100-A...
# 3  http://www.amazon.co.uk/Namco-Bandai-Icarly/dp...
# 4  http://www.amazon.co.uk/20-Packs-Wax-Crayons-P...
#
#                       customer_questions_and_answers  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  How many packs in the box. // I got four Mimi ...
#
#                                     customer_reviews
# 0  Fascinating fun // 4.0 // 25 Nov. 2008 // By\n...
# 1  Never Too Old // 4.0 // 6 Nov. 2013 // By\n   ...
# 2  Great item // 4.0 // 27 Dec. 2015 // By\n    \...
# 3  Very good product // 5.0 // 26 Mar. 2014 // By...
# 4  Well made and presented // 4.0 // 6 April 2015...

# %%
amazon.dtypes
# Out:
# uniq_id                                         object
# product_name                                    object
# manufacturer                                    object
# price                                          float64
# number_available_in_stock                        int64
# status                                          object
# number_of_reviews                                int64
# number_of_answered_questions                     int64
# average_review_rating_of_5                     float64
# amazon_category_and_sub_category                object
# customers_who_bought_this_item_also_bought      object
# description                                     object
# product_information                             object
# product_description                             object
# items_customers_buy_after_viewing_this_item     object
# customer_questions_and_answers                  object
# customer_reviews                                object
# dtype: object

# %%
plt.scatter(amazon['average_review_rating_of_5'], amazon['number_of_answered_questions'], alpha=0.5)
plt.title('Scatter plot average_review_rating_of_5 vs. number_of_answered_questions')
plt.xlabel('average_review_rating_of_5')
plt.ylabel('number_of_answered_questions')
plt.show()

# %%
plt.scatter(amazon['average_review_rating_of_5'], amazon['number_of_reviews'], alpha=0.5)
plt.title('Scatter plot average_review_rating_of_5 vs. number_of_reviews')
plt.xlabel('average_review_rating_of_5')
plt.ylabel('number_of_reviews')
plt.show()

# %%
plt.scatter(amazon['average_review_rating_of_5'], amazon['number_of_reviews'], alpha=0.5)
plt.title('Scatter plot average_review_rating_of_5 vs. number_available_in_stock')
plt.xlabel('average_review_rating_of_5')
plt.ylabel('number_available_in_stock')
plt.show()

# %%
amazon.corr()
# Out:
#                                  price  number_available_in_stock  \
# price                         1.000000                  -0.018077
# number_available_in_stock    -0.018077                   1.000000
# number_of_reviews            -0.024214                   0.216765
# number_of_answered_questions -0.005956                  -0.008131
# average_review_rating_of_5    0.013431                  -0.010505
#
#                               number_of_reviews  number_of_answered_questions  \
# price                                 -0.024214                     -0.005956
# number_available_in_stock              0.216765                     -0.008131
# number_of_reviews                      1.000000                      0.020981
# number_of_answered_questions           0.020981                      1.000000
# average_review_rating_of_5            -0.090466                      0.001997
#
#                               average_review_rating_of_5
# price                                           0.013431
# number_available_in_stock                      -0.010505
# number_of_reviews                              -0.090466
# number_of_answered_questions                    0.001997
# average_review_rating_of_5                      1.000000

# %%
X1 = amazon[['number_of_answered_questions','number_of_reviews','number_available_in_stock']]
y1 = amazon['average_review_rating_of_5']
X1 = sm.add_constant(X1)
amazon.mod1 = sm.OLS(y1, X1).fit()  ## sm.OLS(output, i.e. dependent variable, input, i.e. independent variable)
amazon.mod1_summary = amazon.mod1.summary()
print(amazon.mod1_summary)
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     average_review_rating_of_5   R-squared:                       0.008
# Model:                                    OLS   Adj. R-squared:                  0.008
# Method:                         Least Squares   F-statistic:                     17.64
# Date:                        Sat, 18 Jun 2022   Prob (F-statistic):           2.13e-11
# Time:                                04:22:27   Log-Likelihood:                -3581.5
# No. Observations:                        6336   AIC:                             7171.
# Df Residuals:                            6332   BIC:                             7198.
# Df Model:                                   3
# Covariance Type:                    nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                            4.6931      0.008    618.001      0.000       4.678       4.708
# number_of_answered_questions     0.0001      0.000      0.321      0.748      -0.001       0.001
# number_of_reviews               -0.0010      0.000     -7.224      0.000      -0.001      -0.001
# number_available_in_stock        0.0005      0.001      0.749      0.454      -0.001       0.002
# ==============================================================================
# Omnibus:                     5137.582   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           269940.856
# Skew:                          -3.497   Prob(JB):                         0.00
# Kurtosis:                      34.202   Cond. No.                         58.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
X = amazon['average_review_rating_of_5']
y = amazon['number_of_answered_questions']
X = sm.add_constant(X)
amazon.mod1 = sm.OLS(y, X).fit()  ## sm.OLS(output, i.e. dependent variable, input, i.e. independent variable)
amazon.mod1_summary = amazon.mod1.summary()
print(amazon.mod1_summary)
# Out:
#                                  OLS Regression Results
# ========================================================================================
# Dep. Variable:     number_of_answered_questions   R-squared:                       0.000
# Model:                                      OLS   Adj. R-squared:                 -0.000
# Method:                           Least Squares   F-statistic:                   0.02526
# Date:                          Sat, 18 Jun 2022   Prob (F-statistic):              0.874
# Time:                                  04:14:58   Log-Likelihood:                -25442.
# No. Observations:                          6336   AIC:                         5.089e+04
# Df Residuals:                              6334   BIC:                         5.090e+04
# Df Model:                                     1
# Covariance Type:                      nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          3.6341      1.855      1.959      0.050      -0.003       7.271
# average_review_rating_of_5     0.0627      0.394      0.159      0.874      -0.710       0.835
# ==============================================================================
# Omnibus:                    14385.216   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        140467264.986
# Skew:                          21.389   Prob(JB):                         0.00
# Kurtosis:                     731.178   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
X = amazon['average_review_rating_of_5']
y = amazon['price']
X = sm.add_constant(X)
amazon.mod1 = sm.OLS(y, X).fit()  ## sm.OLS(output, i.e. dependent variable, input, i.e. independent variable)
amazon.mod1_summary = amazon.mod1.summary()
print(amazon.mod1_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.143
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):              0.285
# Time:                        19:17:27   Log-Likelihood:                -33287.
# No. Observations:                6336   AIC:                         6.658e+04
# Df Residuals:                    6334   BIC:                         6.659e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         13.4010      6.399      2.094      0.036       0.857      25.945
# average_review_rating_of_5     1.4538      1.360      1.069      0.285      -1.212       4.120
# ==============================================================================
# Omnibus:                    15757.654   Durbin-Watson:                   0.166
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        399417628.621
# Skew:                          26.461   Prob(JB):                         0.00
# Kurtosis:                    1231.880   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
X = amazon['average_review_rating_of_5']
y = amazon['number_of_reviews']
X = sm.add_constant(X)
amazon.mod1 = sm.OLS(y, X).fit()  ## sm.OLS(output, i.e. dependent variable, input, i.e. independent variable)
amazon.mod1_summary = amazon.mod1.summary()
print(amazon.mod1_summary)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      number_of_reviews   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     52.27
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):           5.42e-13
# Time:                        19:17:31   Log-Likelihood:                -32224.
# No. Observations:                6336   AIC:                         6.445e+04
# Df Residuals:                    6334   BIC:                         6.446e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         50.1717      5.410      9.273      0.000      39.566      60.778
# average_review_rating_of_5    -8.3120      1.150     -7.229      0.000     -10.566      -6.058
# ==============================================================================
# Omnibus:                    12629.640   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         43359052.990
# Skew:                          16.019   Prob(JB):                         0.00
# Kurtosis:                     406.996   Cond. No.                         54.1
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
print('Parameters: ', amazon.mod1.params)
print('R2: ', amazon.mod1.rsquared)
# Out:
# Parameters:  const                         13.400974
# average_review_rating_of_5     1.453773
# dtype: float64
# R2:  0.00018040239456351692

# %%
predictions = amazon.mod1.predict(X) # Here, you'll see the CALCULATED values with the formula
predictions
# Out:
# 0       19.216067
# 1       19.942953
# 2       19.942953
# 3       20.088331
# 4       19.652199
#           ...
# 6331    18.198426
# 6332    20.669840
# 6333    20.669840
# 6334    20.669840
# 6335    19.216067
# Length: 6336, dtype: float64

# %%
X = amazon[['price','number_of_answered_questions','number_of_reviews']] # Now we have values from three different independent attributes stored in X
y = amazon['average_review_rating_of_5'] # This is, again, our dependent attribute
print(X) # This is the content of our X variable
# Out:
#         price  number_of_answered_questions  number_of_reviews
# 0        0.29                             2                  3
# 1        0.38                             1                  2
# 2        0.39                             1                  2
# 3        0.50                             2                  7
# 4        0.60                             1                 21
# ...       ...                           ...                ...
# 6331   439.95                             3                  9
# 6332   447.99                             3                  1
# 6333   719.95                             1                  1
# 6334   995.11                            19                  4
# 6335  2439.92                             1                  1
#
# [6336 rows x 3 columns]

# %%
lm = linear_model.LinearRegression() # Here, we are using the linear_model subpackage from scikit-learn that we imported above
model = lm.fit(X,y) # And here, we are building

# %%
lm.score(X,y)
# Out:
# 0.008326162044344776

# %%
lm.coef_
# Out:
# array([ 0.00010411,  0.00012615, -0.00098255])

# %%
lm.intercept_
# Out:
# 4.694645761442997

# %%
amazon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6336 entries, 0 to 6335
# Data columns (total 17 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   uniq_id                                      6336 non-null   object
#  1   product_name                                 6336 non-null   object
#  2   manufacturer                                 6336 non-null   object
#  3   price                                        6336 non-null   float64
#  4   number_available_in_stock                    6336 non-null   int64
#  5   status                                       6336 non-null   object
#  6   number_of_reviews                            6336 non-null   int64
#  7   number_of_answered_questions                 6336 non-null   int64
#  8   average_review_rating_of_5                   6336 non-null   float64
#  9   amazon_category_and_sub_category             6336 non-null   object
#  10  customers_who_bought_this_item_also_bought   6336 non-null   object
#  11  description                                  6335 non-null   object
#  12  product_information                          6313 non-null   object
#  13  product_description                          6335 non-null   object
#  14  items_customers_buy_after_viewing_this_item  6336 non-null   object
#  15  customer_questions_and_answers               6336 non-null   object
#  16  customer_reviews                             6336 non-null   object
# dtypes: float64(2), int64(3), object(12)
# memory usage: 841.6+ KB

# %%
amazon2 = pd.read_csv("https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/amazon_toy_sample_clean.csv", encoding="ISO-8859-1")
amazon2.head()
# Out:
#                             uniq_id  \
# 0  dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1  ba85fb9368114fce646379ed12750a5f
# 2  14e24c29ba38c2717754baa2638f242a
# 3  048d64d2ba61c23f6280663a7281ff19
# 4  7b72f597db5d74d35c4f91ef69708cf1
#
#                                         product_name  \
# 0                                      Dinosaur Eggs
# 1   Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2          Latex Assorted Water Balloons, Pack of 40
# 3                iCarly Shopper Bag - Lilac and Pink
# 4  4 Packs of Mini Colouring Pencils (4 pencils i...
#
#                manufacturer  price  number_available_in_stock status  \
# 0                   Halsall   0.29                          3    new
# 1                   Neopets   0.38                          2    new
# 2              Unique Party   0.39                          7    new
# 3    Trade Mark Collections   0.50                          4    new
# 4  unisex party bag fillers   0.60                          7    new
#
#    number_of_reviews  number_of_answered_questions  \
# 0                  3                             2
# 1                  2                             1
# 2                  2                             1
# 3                  7                             2
# 4                 21                             1
#
#    average_review_rating_of_5  \
# 0                         4.0
# 1                         4.5
# 2                         4.5
# 3                         4.6
# 4                         4.3
#
#                     amazon_category_and_sub_category  \
# 0                     Figures & Playsets > Dinosaurs
# 1  Hobbies > Trading Cards & Accessories > Packs ...
# 2            Party Supplies > Decorations > Balloons
# 3  Sports Toys & Outdoor > Beach Toys > Airbeds &...
# 4                  Arts & Crafts > Colouring Pencils
#
#           customers_who_bought_this_item_also_bought  \
# 0  http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                            Unknown
# 2  http://www.amazon.co.uk/Latex-Cannonball | htt...
# 3  http://www.amazon.co.uk/iCarly-Large-Rectangle...
# 4  http://www.amazon.co.uk/12-Mini-Christmas-Colo...
#
#                                          description  \
# 0           Manufacturer's Description not available
# 1           Manufacturer's Description not available
# 2  Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3  Manufacturer's Description The iCarly Shopping...
# 4  4 x Mini Colouring Pencils - Pack of 4 Size: 8...
#
#                                  product_information  \
# 0  Technical Details Item Weight82 g Product Dime...
# 1  Technical Details Item Weight454 g Product Dim...
# 2  Technical Details Item Weight222 g Product Dim...
# 3                                                NaN
# 4  Technical Details Item Weight59 g Product Dime...
#
#                                  product_description  \
# 0                                      Not available
# 1                                      Not available
# 2  Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3  Manufacturer's Description The iCarly Shopping...
# 4  4 x Mini Colouring Pencils - Pack of 4 Size: 8...
#
#          items_customers_buy_after_viewing_this_item  \
# 0  http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                      Not available
# 2  http://www.amazon.co.uk/Water-Bombs-Pack-100-A...
# 3  http://www.amazon.co.uk/Namco-Bandai-Icarly/dp...
# 4  http://www.amazon.co.uk/20-Packs-Wax-Crayons-P...
#
#                       customer_questions_and_answers  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  How many packs in the box. // I got four Mimi ...
#
#                                     customer_reviews
# 0  Fascinating fun // 4.0 // 25 Nov. 2008 // By\n...
# 1  Never Too Old // 4.0 // 6 Nov. 2013 // By\n   ...
# 2  Great item // 4.0 // 27 Dec. 2015 // By\n    \...
# 3  Very good product // 5.0 // 26 Mar. 2014 // By...
# 4  Well made and presented // 4.0 // 6 April 2015...

# %%
# Creating a new attribute and populating it with the contents of the attribute that we want to transform.
status_num=amazon2.status

# Adding the new attribute to the dataframe
amazon2['status_num'] = status_num

# Checking the contents of the new attribute
amazon2.status_num
amazon2['status_num']= amazon2['status_num'].astype('category')

# Now we replace the categories with their index numbers, i.e. the category codes
amazon2['status_num']= amazon2['status_num'].cat.codes

# Let's see what the datatypes look like now
amazon2.dtypes[['status','status_num']]
# Out:
# status        object
# status_num      int8
# dtype: object

# %%
del amazon2['manufacturer']
del amazon2['amazon_category_and_sub_category']
del amazon2['customers_who_bought_this_item_also_bought']
del amazon2['description']
del amazon2['product_information']
del amazon2['product_description']
del amazon2['items_customers_buy_after_viewing_this_item']
del amazon2['customer_questions_and_answers']
del amazon2['customer_reviews']
del amazon2['status']
del amazon2['uniq_id']
del amazon2['product_name']
amazon2.head()
# Out:
#    price  number_available_in_stock  number_of_reviews  \
# 0   0.29                          3                  3
# 1   0.38                          2                  2
# 2   0.39                          7                  2
# 3   0.50                          4                  7
# 4   0.60                          7                 21
#
#    number_of_answered_questions  average_review_rating_of_5  status_num
# 0                             2                         4.0           1
# 1                             1                         4.5           1
# 2                             1                         4.5           1
# 3                             2                         4.6           1
# 4                             1                         4.3           1

# %%
X = amazon2.iloc[:, :-1].values
y = amazon2.iloc[:, 5].values
print(X)
print(y)
# Out:
# [[2.90000e-01 3.00000e+00 3.00000e+00 2.00000e+00 4.00000e+00]
#  [3.80000e-01 2.00000e+00 2.00000e+00 1.00000e+00 4.50000e+00]
#  [3.90000e-01 7.00000e+00 2.00000e+00 1.00000e+00 4.50000e+00]
#  ...
#  [7.19950e+02 2.00000e+00 1.00000e+00 1.00000e+00 5.00000e+00]
#  [9.95110e+02 2.00000e+00 4.00000e+00 1.90000e+01 5.00000e+00]
#  [2.43992e+03 2.00000e+00 1.00000e+00 1.00000e+00 4.00000e+00]]
# [1 1 1 ... 1 3 1]

# %%
amazon2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6336 entries, 0 to 6335
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   price                         6336 non-null   float64
#  1   number_available_in_stock     6336 non-null   int64
#  2   number_of_reviews             6336 non-null   int64
#  3   number_of_answered_questions  6336 non-null   int64
#  4   average_review_rating_of_5    6336 non-null   float64
#  5   status_num                    6336 non-null   int8
# dtypes: float64(2), int64(3), int8(1)
# memory usage: 253.8 KB

# %%
X = amazon2.iloc[:, :-1].values
y = amazon2.iloc[:, 5].values

X = np.append(arr = np.ones((6336, 1)).astype(int), values = X, axis = 1) # We are building our numpy array

X_opt = X[:, [0, 1, 2, 3, 4, 5]] # Now we combine all 6 input variables into our first iteration
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit() # Now we set up our regressor function with OLS again as before.
print(regressor_OLS.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     10.66
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):           3.24e-10
# Time:                        14:11:35   Log-Likelihood:                 1431.5
# No. Observations:                6336   AIC:                            -2851.
# Df Residuals:                    6330   BIC:                            -2810.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0767      0.027     39.919      0.000       1.024       1.130
# x1             0.0003   5.24e-05      4.936      0.000       0.000       0.000
# x2            -0.0013      0.000     -4.847      0.000      -0.002      -0.001
# x3          1.469e-05   6.35e-05      0.231      0.817      -0.000       0.000
# x4          8.021e-05      0.000      0.443      0.657      -0.000       0.000
# x5            -0.0114      0.006     -2.004      0.045      -0.023      -0.000
# ==============================================================================
# Omnibus:                     9497.655   Durbin-Watson:                   1.800
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2554644.386
# Skew:                           9.513   Prob(JB):                         0.00
# Kurtosis:                      99.513   Cond. No.                         580.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_opt = X[:, [1, 2, 3, 4, 5]] 
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit() # Now we set up our regressor function with OLS again as before.
print(regressor_OLS.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   3.548
# Model:                            OLS   Adj. R-squared (uncentered):              3.550
# Method:                 Least Squares   F-statistic:                             -1763.
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):                        1.00
# Time:                        15:15:54   Log-Likelihood:                          720.15
# No. Observations:                6336   AIC:                                     -1430.
# Df Residuals:                    6331   BIC:                                     -1397.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0003   5.86e-05      5.478      0.000       0.000       0.000
# x2            -0.0005      0.000     -1.698      0.090      -0.001    7.99e-05
# x3             0.0003   7.08e-05      3.675      0.000       0.000       0.000
# x4             0.0002      0.000      1.219      0.223      -0.000       0.001
# x5             0.2140      0.001    250.291      0.000       0.212       0.216
# ==============================================================================
# Omnibus:                     8203.237   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1209370.314
# Skew:                           7.359   Prob(JB):                         0.00
# Kurtosis:                      69.063   Cond. No.                         16.5
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_opt = X[:, [0, 1, 3, 4, 5]] # 
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit() # Now we set up our regressor function with OLS again as before.
print(regressor_OLS.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     7.422
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):           5.84e-06
# Time:                        14:11:46   Log-Likelihood:                 1419.8
# No. Observations:                6336   AIC:                            -2830.
# Df Residuals:                    6331   BIC:                            -2796.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0670      0.027     39.599      0.000       1.014       1.120
# x1             0.0003   5.25e-05      4.992      0.000       0.000       0.000
# x2         -5.204e-05   6.21e-05     -0.837      0.402      -0.000    6.98e-05
# x3           9.17e-05      0.000      0.506      0.613      -0.000       0.000
# x4            -0.0117      0.006     -2.047      0.041      -0.023      -0.000
# ==============================================================================
# Omnibus:                     9535.681   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2599911.658
# Skew:                           9.585   Prob(JB):                         0.00
# Kurtosis:                     100.369   Cond. No.                         577.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_opt = X[:, [0, 1, 3, 4]] 
regressor_OLS = sm.OLS(endog = y, exog = X_opt).fit() # Now we set up our regressor function with OLS again as before.
print(regressor_OLS.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     8.495
# Date:                Fri, 17 Jun 2022   Prob (F-statistic):           1.25e-05
# Time:                        14:11:54   Log-Likelihood:                 1417.7
# No. Observations:                6336   AIC:                            -2827.
# Df Residuals:                    6332   BIC:                            -2800.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.0122      0.003    356.720      0.000       1.007       1.018
# x1             0.0003   5.25e-05      4.968      0.000       0.000       0.000
# x2         -4.056e-05   6.19e-05     -0.655      0.512      -0.000    8.08e-05
# x3          9.023e-05      0.000      0.498      0.619      -0.000       0.000
# ==============================================================================
# Omnibus:                     9540.624   Durbin-Watson:                   1.802
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2606147.795
# Skew:                           9.594   Prob(JB):                         0.00
# Kurtosis:                     100.486   Cond. No.                         59.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
amazon3 = amazon2
amazon3.head()
# Out:
#    price  number_available_in_stock  number_of_reviews  \
# 0   0.29                          3                  3
# 1   0.38                          2                  2
# 2   0.39                          7                  2
# 3   0.50                          4                  7
# 4   0.60                          7                 21
#
#    number_of_answered_questions  average_review_rating_of_5  status_num
# 0                             2                         4.0           1
# 1                             1                         4.5           1
# 2                             1                         4.5           1
# 3                             2                         4.6           1
# 4                             1                         4.3           1

# %%
corr = amazon3.corr()
corr
# Out:
#                                  price  number_available_in_stock  \
# price                         1.000000                  -0.018077
# number_available_in_stock    -0.018077                   1.000000
# number_of_reviews            -0.024214                   0.216765
# number_of_answered_questions -0.005956                  -0.008131
# average_review_rating_of_5    0.013431                  -0.010505
# status_num                    0.062485                  -0.062411
#
#                               number_of_reviews  number_of_answered_questions  \
# price                                 -0.024214                     -0.005956
# number_available_in_stock              0.216765                     -0.008131
# number_of_reviews                      1.000000                      0.020981
# number_of_answered_questions           0.020981                      1.000000
# average_review_rating_of_5            -0.090466                      0.001997
# status_num                            -0.009599                      0.005701
#
#                               average_review_rating_of_5  status_num
# price                                           0.013431    0.062485
# number_available_in_stock                      -0.010505   -0.062411
# number_of_reviews                              -0.090466   -0.009599
# number_of_answered_questions                    0.001997    0.005701
# average_review_rating_of_5                      1.000000   -0.023960
# status_num                                     -0.023960    1.000000

# %%
import seaborn as sns

f, ax = plt.subplots(figsize = (10, 10))
sns.heatmap(corr, mask = np.zeros_like(corr, dtype = np.bool), 
            cmap = sns.diverging_palette(150, 275, as_cmap = True), square = True, ax = ax)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.

# %%
dfTrain = amazon3[:2000]
dfTest = amazon3[2000:4000]
dfCheck = amazon3[4000:]

# %%
train_y = np.asarray(dfTrain['number_of_reviews']) # We store insuranceclaim in train_y, but as numpy array
train_x = np.asarray(dfTrain.drop('number_of_reviews',1)) # We remove insurancelcaim from the predictors (because it's the output variable)
test_y = np.asarray(dfTest['number_of_reviews']) # See the comments above
test_x = np.asarray(dfTest.drop('number_of_reviews',1))
train_x
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.
# array([[ 0.29,  3.  ,  2.  ,  4.  ,  1.  ],
#        [ 0.38,  2.  ,  1.  ,  4.5 ,  1.  ],
#        [ 0.39,  7.  ,  1.  ,  4.5 ,  1.  ],
#        ...,
#        [ 6.99,  9.  ,  1.  ,  5.  ,  1.  ],
#        [ 7.  , 10.  ,  1.  ,  4.8 ,  1.  ],
#        [ 7.  ,  2.  ,  1.  ,  5.  ,  1.  ]])

# %%
means = np.mean(train_x, axis=0)
std = np.std(train_x, axis=0)
 
train_x = (train_x - means)/std
test_x = (test_x - means)/std

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# LogisticRegression()

# %%
accuracy = model.score(test_x, test_y)
print("accuracy = ", accuracy * 100, "%")
# Out:
# accuracy =  35.949999999999996 %

# %%
pred = model.predict(test_x)
print(pred)
# Out:
# [  1   1   1 ...   1   1 690]

# %%
realvsmodel = pd.DataFrame(pred,test_y)
realvsmodel = pd.DataFrame({'predicted':pred,'original':test_y})
realvsmodel.head(25)
# Out:
#     predicted  original
# 0           1         1
# 1           1         6
# 2           1         1
# 3           1         6
# 4           1         2
# 5           1         3
# 6           1        30
# 7           1         1
# 8           1         3
# 9           1         4
# 10          1         4
# 11          1         1
# 12          1         1
# 13          1         1
# 14          1        33
# 15         66        33
# 16          1         5
# 17          1         2
# 18          1        57
# 19          1         5
# 20          1         3
# 21          1        12
# 22          1         6
# 23          1         1
# 24          1         2

# %%
corr = amazon.corr()
corr
# Out:
#                                  price  number_available_in_stock  \
# price                         1.000000                  -0.018077
# number_available_in_stock    -0.018077                   1.000000
# number_of_reviews            -0.024214                   0.216765
# number_of_answered_questions -0.005956                  -0.008131
# average_review_rating_of_5    0.013431                  -0.010505
#
#                               number_of_reviews  number_of_answered_questions  \
# price                                 -0.024214                     -0.005956
# number_available_in_stock              0.216765                     -0.008131
# number_of_reviews                      1.000000                      0.020981
# number_of_answered_questions           0.020981                      1.000000
# average_review_rating_of_5            -0.090466                      0.001997
#
#                               average_review_rating_of_5
# price                                           0.013431
# number_available_in_stock                      -0.010505
# number_of_reviews                              -0.090466
# number_of_answered_questions                    0.001997
# average_review_rating_of_5                      1.000000

# %%
bins = np.linspace(amazon.average_review_rating_of_5.min(), amazon.average_review_rating_of_5.max(), 3) 
# Define the two labels. 
labels = ['Low Rating', 'High Rating']  
# Add bins to the dataset. 
amazon['bins'] = pd.cut(amazon['average_review_rating_of_5'], bins = bins, labels = labels, include_lowest = True) 
amazon
# Out:
#                                uniq_id  \
# 0     dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1     ba85fb9368114fce646379ed12750a5f
# 2     14e24c29ba38c2717754baa2638f242a
# 3     048d64d2ba61c23f6280663a7281ff19
# 4     7b72f597db5d74d35c4f91ef69708cf1
# ...                                ...
# 6331  8020c8cd2b86bd2e793241dd321d8921
# 6332  ddd1807f90417adcdf4cd45841239e01
# 6333  1e897bf37e4e89aba7cc962f24913fd4
# 6334  4f705c302bdcf5d2b0c1df973d98f99f
# 6335  75d96583894e50412ba5c0161375fef5
#
#                                            product_name  \
# 0                                         Dinosaur Eggs
# 1      Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2             Latex Assorted Water Balloons, Pack of 40
# 3                   iCarly Shopper Bag - Lilac and Pink
# 4     4 Packs of Mini Colouring Pencils (4 pencils i...
# ...                                                 ...
# 6331                       Parrot Bebop Drone 2 (White)
# 6332  Star Images E.T. Stunt Puppet Replica Action F...
# 6333  Indiana Jones - 12 Inch Action Figures: Indian...
# 6334                    DJI Phantom 2 with H3-3D Gimbal
# 6335  Bowen Designs - Marvel Statue Thor Classic Act...
#
#                   manufacturer    price  number_available_in_stock status  \
# 0                      Halsall     0.29                          3    new
# 1                      Neopets     0.38                          2    new
# 2                 Unique Party     0.39                          7    new
# 3       Trade Mark Collections     0.50                          4    new
# 4     unisex party bag fillers     0.60                          7    new
# ...                        ...      ...                        ...    ...
# 6331                    Parrot   439.95                         11    new
# 6332               Star images   447.99                          3    new
# 6333                  Sideshow   719.95                          2    new
# 6334                       DJI   995.11                          2   used
# 6335             Bowen Designs  2439.92                          2    new
#
#       number_of_reviews  number_of_answered_questions  \
# 0                     3                             2
# 1                     2                             1
# 2                     2                             1
# 3                     7                             2
# 4                    21                             1
# ...                 ...                           ...
# 6331                  9                             3
# 6332                  1                             3
# 6333                  1                             1
# 6334                  4                            19
# 6335                  1                             1
#
#       average_review_rating_of_5  \
# 0                            4.0
# 1                            4.5
# 2                            4.5
# 3                            4.6
# 4                            4.3
# ...                          ...
# 6331                         3.3
# 6332                         5.0
# 6333                         5.0
# 6334                         5.0
# 6335                         4.0
#
#                        amazon_category_and_sub_category  \
# 0                        Figures & Playsets > Dinosaurs
# 1     Hobbies > Trading Cards & Accessories > Packs ...
# 2               Party Supplies > Decorations > Balloons
# 3     Sports Toys & Outdoor > Beach Toys > Airbeds &...
# 4                     Arts & Crafts > Colouring Pencils
# ...                                                 ...
# 6331  Hobbies > Remote Controlled Devices > Helicopt...
# 6332                   Figures & Playsets > Accessories
# 6333     Figures & Playsets > Science Fiction & Fantasy
# 6334  Hobbies > Remote Controlled Devices > Helicopt...
# 6335  Hobbies > Model Trains & Railway Sets > Access...
#
#              customers_who_bought_this_item_also_bought  \
# 0     http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                               Unknown
# 2     http://www.amazon.co.uk/Latex-Cannonball | htt...
# 3     http://www.amazon.co.uk/iCarly-Large-Rectangle...
# 4     http://www.amazon.co.uk/12-Mini-Christmas-Colo...
# ...                                                 ...
# 6331  http://www.amazon.co.uk/BTG-Upgrade-Battery310...
# 6332  http://www.amazon.co.uk/12-Inch-Replica-Stunt-...
# 6333  http://www.amazon.co.uk/Indiana-Jones-Masterpi...
# 6334  http://www.amazon.co.uk/Propellers | http://ww...
# 6335  http://www.amazon.co.uk/Kotobukiya | http://ww...
#
#                                             description  \
# 0              Manufacturer's Description not available
# 1              Manufacturer's Description not available
# 2     Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3     Manufacturer's Description The iCarly Shopping...
# 4     4 x Mini Colouring Pencils - Pack of 4 Size: 8...
# ...                                                 ...
# 6331  Colour Name:White and Black Product Descriptio...
# 6332  Product Description E.T. Stunt Puppet Replica ...
# 6333  Figurine articulÃ©e taille env. 30 cm avec vÃª...
# 6334  Product Description Including the H3-3D Gimbal...
# 6335  Sideshow Collectibles is proud to present the ...
#
#                                     product_information  \
# 0     Technical Details Item Weight82 g Product Dime...
# 1     Technical Details Item Weight454 g Product Dim...
# 2     Technical Details Item Weight222 g Product Dim...
# 3                                                   NaN
# 4     Technical Details Item Weight59 g Product Dime...
# ...                                                 ...
# 6331  Technical Details Item Weight503 g Product Dim...
# 6332  Technical Details Item Weight998 g Product Dim...
# 6333  Technical Details Item Weight1.1 Kg Product Di...
# 6334  Technical Details Item Weight2.5 Kg Product Di...
# 6335  Technical Details Item Weight6 Kg Product Dime...
#
#                                     product_description  \
# 0                                         Not available
# 1                                         Not available
# 2     Colour Name:Assorted Bold  |  Size Name:Pack o...
# 3     Manufacturer's Description The iCarly Shopping...
# 4     4 x Mini Colouring Pencils - Pack of 4 Size: 8...
# ...                                                 ...
# 6331  Colour Name:White and Black Product Descriptio...
# 6332  Product Description E.T. Stunt Puppet Replica ...
# 6333  Figurine articulÃ©e taille env. 30 cm avec vÃª...
# 6334  Product Description Including the H3-3D Gimbal...
# 6335  Sideshow Collectibles is proud to present the ...
#
#             items_customers_buy_after_viewing_this_item  \
# 0     http://www.amazon.co.uk/Hatch-em-TY63-Hatching...
# 1                                         Not available
# 2     http://www.amazon.co.uk/Water-Bombs-Pack-100-A...
# 3     http://www.amazon.co.uk/Namco-Bandai-Icarly/dp...
# 4     http://www.amazon.co.uk/20-Packs-Wax-Crayons-P...
# ...                                                 ...
# 6331                                      Not available
# 6332  http://www.amazon.co.uk/12-Inch-Replica-Stunt-...
# 6333                                      Not available
# 6334                                      Not available
# 6335                                      Not available
#
#                          customer_questions_and_answers  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4     How many packs in the box. // I got four Mimi ...
# ...                                                 ...
# 6331  Can you use the skycontroller from the origina...
# 6332  Is this made by Neca and is it the 3 foot life...
# 6333                                               None
# 6334  Does this come with the gimbal already install...
# 6335                                               None
#
#                                        customer_reviews         bins
# 0     Fascinating fun // 4.0 // 25 Nov. 2008 // By\n...  High Rating
# 1     Never Too Old // 4.0 // 6 Nov. 2013 // By\n   ...  High Rating
# 2     Great item // 4.0 // 27 Dec. 2015 // By\n    \...  High Rating
# 3     Very good product // 5.0 // 26 Mar. 2014 // By...  High Rating
# 4     Well made and presented // 4.0 // 6 April 2015...  High Rating
# ...                                                 ...          ...
# 6331  Much improved but slightly weird incremental u...  High Rating
# 6332  Five Stars // 5.0 // 25 Oct. 2014 // By\n    \...  High Rating
# 6333  "It's not the years, sweet heart, it's the mil...  High Rating
# 6334  Dji // 5.0 // 24 Aug. 2014 // By\n    \n    ol...  High Rating
# 6335  Thortastic... // 4.0 // 12 Sept. 2012 // By\n ...  High Rating
#
# [6336 rows x 18 columns]
