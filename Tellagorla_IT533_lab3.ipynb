# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import math
from math import acos, degrees
from scipy import spatial
from scipy.stats import chisquare
from scipy.stats import chi2_contingency
from sklearn.metrics.pairwise import cosine_similarity
amazon = pd.read_csv("https://raw.githubusercontent.com/shstreuber/Data-Mining/master/data/amazon_toy_sample_clean.csv", encoding="ISO-8859-1") # use your own GitHub link here
amazon.dropna(inplace=True)

# %%
amazon
# Out:
#                                uniq_id  \
# 0     dafc6b4ba4b4a3e7b4ff83402a196ae8
# 1     ba85fb9368114fce646379ed12750a5f
# 2     14e24c29ba38c2717754baa2638f242a
# 4     7b72f597db5d74d35c4f91ef69708cf1
# 5     7b8a04095b5e4984c57fd45eb327feb1
# ...                                ...
# 6331  8020c8cd2b86bd2e793241dd321d8921
# 6332  ddd1807f90417adcdf4cd45841239e01
# 6333  1e897bf37e4e89aba7cc962f24913fd4
# 6334  4f705c302bdcf5d2b0c1df973d98f99f
# 6335  75d96583894e50412ba5c0161375fef5
#
#                                            product_name  \
# 0                                         Dinosaur Eggs
# 1      Neopets 4 Trading Card Fun Packs (2 Bonus Cards)
# 2             Latex Assorted Water Balloons, Pack of 40
# 4     4 Packs of Mini Colouring Pencils (4 pencils i...
# 5     100 Deep Red Rose Silk Petals Confetti - Weddi...
# ...                                                 ...
# 6331                       Parrot Bebop Drone 2 (White)
# ...

# %%
dot = np.dot(a, b)  # computing the dot product with the dot function
norma = np.linalg.norm(a)  # normalizing vector a
normb = np.linalg.norm(b)  # normalizing vector b
cos1 = dot / (norma * normb)  # computing the cosine by dividing the dot product by the normalized vectors as shown in the cartoon above

print(cos1)
# Out:
# 0.3996403230765079

# %%
angle_in_radians1 = math.acos(cos1)
degrees1 = math.degrees(angle_in_radians1)

# %%
a = np.array(amazon.average_review_rating_of_5)
b = np.array(amazon.price)

# Manually computing cosine similarity
dot = np.dot(a, b)  # the dot product
norma = np.linalg.norm(a)  # normalizing vector a
normb = np.linalg.norm(b)  # normalizing vector b
cos1 = dot / (norma * normb)  # computing the angle by dividing the dot product by the normalized vectors

print(cos1, angle_in_radians1, degrees1)
# Out:
# 0.3996403230765079 1.1596718868327873 66.44430473549154

# %%
a = np.array(amazon.number_available_in_stock)
b = np.array(amazon.price)

# Manually computing cosine similarity
dot = np.dot(a, b)  # the dot product
norma = np.linalg.norm(a)  # normalizing vector a
normb = np.linalg.norm(b)  # normalizing vector b
cos1 = dot / (norma * normb)
print(cos1, angle_in_radians1, degrees1)
# Out:
# 0.264714363078917 1.1596718868327873 66.44430473549154

# %%
aa = a.reshape(1,6312) # we have 3 values in our array
ba = b.reshape(1,6312) # we have 3 values in our array
cos3 = cosine_similarity(aa, ba)

# Now we need to convert the angle to radians to get the degrees
angle_in_radians3 = math.acos(cos3)
degrees3 = math.degrees(angle_in_radians3)

# %%
angle_in_radians3 = math.acos(cos3)
degrees3 = math.degrees(angle_in_radians3)

# %%
a = np.array(amazon.average_review_rating_of_5)
b = np.array(amazon.price)

# Manually computing cosine similarity
dot = np.dot(a, b)  # the dot product
norma = np.linalg.norm(a)  # normalizing vector a
normb = np.linalg.norm(b)  # normalizing vector b
cos3 = dot / (norma * normb)  # computing the angle by dividing the dot product by the normalized vectors

print(cos3, angle_in_radians3, degrees3)
# Out:
# 0.3996403230765079 1.3028886199479024 74.65001909863912

# %%
a = np.array(amazon.number_available_in_stock)
b = np.array(amazon.price)

# Manually computing cosine similarity
dot = np.dot(a, b)  # the dot product
norma = np.linalg.norm(a)  # normalizing vector a
normb = np.linalg.norm(b)  # normalizing vector b
cos3 = dot / (norma * normb)  # computing the angle by dividing the dot product by the normalized vectors

print(cos3, angle_in_radians3, degrees3)
# Out:
# 0.264714363078917 1.3028886199479024 74.65001909863912

# %%
chi2, p, dof, expected = chi2_contingency((pd.crosstab(amazon.number_available_in_stock, amazon.price).values))
print (f'Chi-square Statistic: {chi2} ,p-value: {p}, Degrees of Freedom: {dof}')
# Out:
# Chi-square Statistic: 192838.6163505983 ,p-value: 2.916675652452284e-262, Degrees of Freedom: 171769

# %%
chi2, p, dof, expected = chi2_contingency((pd.crosstab(amazon.average_review_rating_of_5, amazon.price).values))
print (f'Chi-square Statistic: {chi2} ,p-value: {p}, Degrees of Freedom: {dof}')
# Out:
# Chi-square Statistic: 42258.9394991628 ,p-value: 2.2559011134857172e-15, Degrees of Freedom: 40001

# %%
chi2, p, dof, expected = chi2_contingency((pd.crosstab(amazon.price, amazon.amazon_category_and_sub_category).values))
print(f'Chi-square Statistic: {chi2} ,p-value: {p}, Degrees of Freedom: {dof}')
# Out:
# Chi-square Statistic: 491053.6673172697 ,p-value: 0.9990334604576334, Degrees of Freedom: 494130

# %%
np.cov([amazon.average_review_rating_of_5],[amazon.price], ddof=0)[0][1]
# Out:
# 0.2620809838142007

# %%
np.cov([amazon.average_review_rating_of_5],[amazon.price], bias=True)[0][1]
# Out:
# 0.2620809838142007

# %%
np.cov([amazon.average_review_rating_of_5],[amazon.price])[0][1]
# Out:
# 0.2621225114617707

# %%
np.cov([amazon.number_available_in_stock],[amazon.price], ddof=0)[0][1]
# Out:
# -7.716009603491292

# %%
np.cov([amazon.number_available_in_stock],[amazon.price], bias=True)[0][1]
# Out:
# -7.716009603491292

# %%
np.cov([amazon.number_available_in_stock],[amazon.price])[0][1]
# Out:
# -7.717232232171928

# %%
corr_edUSD = amazon['average_review_rating_of_5'].corr(amazon['price'])
corr_edUSD
# Out:
# 0.013213030180579755

# %%
corr_edUSD = amazon['number_available_in_stock'].corr(amazon['price'])
corr_edUSD
# Out:
# -0.01823640563826155

# %%
corr = amazon.corr()
corr
# Out:
#                                  price  number_available_in_stock  \
# price                         1.000000                  -0.018236
# number_available_in_stock    -0.018236                   1.000000
# number_of_reviews            -0.024008                   0.215193
# number_of_answered_questions -0.005889                  -0.008333
# average_review_rating_of_5    0.013213                  -0.009538
#
#                               number_of_reviews  number_of_answered_questions  \
# price                                 -0.024008                     -0.005889
# number_available_in_stock              0.215193                     -0.008333
# number_of_reviews                      1.000000                      0.020904
# number_of_answered_questions           0.020904                      1.000000
# average_review_rating_of_5            -0.089078                      0.001501
#
#                               average_review_rating_of_5
# ...

# %%
plt.scatter(amazon['average_review_rating_of_5'], amazon['price'], alpha=0.5)
plt.title('Scatter plot average_review_rating_of_5 vs. price')
plt.xlabel('average_review_rating_of_5')
plt.ylabel('price')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(corr.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(corr.columns)
ax.set_yticklabels(corr.columns)
plt.show()

# %%
normalized_amazon = amazon[['price', 'number_available_in_stock', 'number_of_reviews', 'number_of_answered_questions', 'average_review_rating_of_5']] 
x = normalized_amazon.values 
min_max_scaler = preprocessing.MinMaxScaler() 
x_scaled = min_max_scaler.fit_transform(x) 
normalized_amazon = pd.DataFrame(x_scaled) 
normalized_amazon=normalized_amazon.rename(columns={0:'price',1:'number_available_in_stock',2:'number_of_reviews',3:'number_of_answered_questions',4:'average_review_rating_of_5'}) 
normalized_amazon
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-30f47cfdfb7a> in <module>()
#       1 normalized_amazon = amazon[['price', 'number_available_in_stock', 'number_of_reviews', 'number_of_answered_questions', 'average_review_rating_of_5']]
#       2 x = normalized_amazon.values
# ----> 3 min_max_scaler = preprocessing.MinMaxScaler()
#       4 x_scaled = min_max_scaler.fit_transform(x)
#       5 normalized_amazon = pd.DataFrame(x_scaled)
#
# NameError: name 'preprocessing' is not defined
